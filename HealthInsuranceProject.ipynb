# %%
#intstalling libraries
#! pip install mysql-connector-python -- already satisfied
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
#!pip install ipython-sql --  already installed

# %%
benefits = pd.read_csv('BenefitsCostSharing.csv')
benefits
# Out:
# C:\Users\chron\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3417: DtypeWarning: Columns (3,6,9,10,16,17,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                              BenefitName  BusinessYear  \
# 0        Routine Dental Services (Adult)          2014
# 1           Dental Check-Up for Children          2014
# 2              Basic Dental Care - Child          2014
# 3                    Orthodontia - Child          2014
# 4              Major Dental Care - Child          2014
# ...                                  ...           ...
# 5048403        Major Dental Care - Child          2016
# 5048404        Basic Dental Care - Adult          2016
# 5048405              Orthodontia - Adult          2016
# 5048406        Major Dental Care - Adult          2016
# 5048407                Accidental Dental          2016
#
# ...

# %%
rules = pd.read_csv('BusinessRules.csv')
rules
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              2014        AL     82285       HIOS           7
# 1              2014        AL     82285       HIOS           7
# 2              2014        AL     82285       HIOS           7
# 3              2014        AL     82285       HIOS           7
# 4              2014        AL     82285       HIOS           7
# ...             ...       ...       ...        ...         ...
# 21080          2016        WV     94562      SERFF           2
# 21081          2016        WV     96480      SERFF           2
# 21082          2016        WV     96480      SERFF           2
# 21083          2016        WV     96480      SERFF           2
# 21084          2016        WV     96480      SERFF           2
#
#                 ImportDate  IssuerId2         TIN   ProductId  \
# 0      2014-01-21 08:29:49      82285  94-2761537         NaN
# 1      2014-01-21 08:29:49      82285  94-2761537         NaN
# ...

# %%
crosswalk2015 = pd.read_csv('Crosswalk2015.csv')
crosswalk2015
# Out:
# C:\Users\chron\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3417: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        State DentalPlan     PlanID_2014  IssuerID_2014 MultistatePlan_2014  \
# 0         AK          Y  21989AK0010001          21989                   N
# 1         AK          Y  21989AK0010001          21989                   N
# 2         AK          Y  21989AK0010001          21989                   N
# 3         AK          Y  21989AK0010001          21989                   N
# 4         AK          Y  21989AK0010001          21989                   N
# ...      ...        ...             ...            ...                 ...
# 132500    WY          Y  83964WY0010004          83964                   N
# 132501    WY          Y  83964WY0010004          83964                   N
# ...

# %%
crosswalk2016 = pd.read_csv('Crosswalk2016.csv')
crosswalk2016
# Out:
#        State DentalPlan     PlanID_2015  IssuerID_2015 MultistatePlan_2015  \
# 0         OR          N  10091OR0360004          10091                   N
# 1         OR          N  10091OR0360004          10091                   N
# 2         OR          N  10091OR0360004          10091                   N
# 3         OR          N  10091OR0360004          10091                   N
# 4         OR          N  10091OR0360004          10091                   N
# ...      ...        ...             ...            ...                 ...
# 150000    OH          Y  99969OH0060005          99969                   N
# 150001    OH          Y  99969OH0060005          99969                   N
# 150002    OH          Y  99969OH0060005          99969                   N
# 150003    OH          Y  99969OH0060005          99969                   N
# 150004    OH          Y  99969OH0060005          99969                   N
#
#        MetalLevel_2015  ChildAdultOnly_2015  FIPSCode  ZipCode  \
# ...

# %%
network = pd.read_csv('Network.csv')
network
# Out:
#       BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0             2014        AK     21989       HIOS           6
# 1             2014        AK     38344       HIOS           6
# 2             2014        AK     38536       HIOS           2
# 3             2014        AK     42507       HIOS           3
# 4             2014        AK     73836       HIOS           6
# ...            ...       ...       ...        ...         ...
# 3817          2016        WV     75441      SERFF           2
# 3818          2016        WV     76526      SERFF           4
# 3819          2016        WV     76526      SERFF           4
# 3820          2016        WV     94562      SERFF           2
# 3821          2016        WV     96480      SERFF           2
#
#                ImportDate  IssuerId2 StateCode2             NetworkName  \
# 0     2014-03-19 07:06:49      21989         AK             ODS Premier
# 1     2013-08-28 08:15:53      38344         AK            HeritagePlus
# ...

# %%
planattributes = pd.read_csv('PlanAttributes.csv')
planattributes
# Out:
# C:\Users\chron\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3417: DtypeWarning: Columns (0,7,8,9,10,11,12,13,14,15,18,19,20,22,23,24,25,26,27,28,29,31,32,33,34,39,40,41,42,66,67,68,70,71,72,75,76,77,79,80,81,82,84,85,86,88,89,90,92,93,94,96,97,98,136,137,138,140,141,142,145,146,147,150,151,152,154,155,156,158,159,160,162,163,164,166,167,168) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       AVCalculatorOutputNumber  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 77348                      NaN
# 77349                      NaN
# 77350                      NaN
# 77351                      NaN
# 77352                      NaN
#
#        BeginPrimaryCareCostSharingAfterNumberOfVisits  \
# ...

# %%
rates = pd.read_csv('Rate.csv')
rates
# Out:
#           BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0                 2014        AK     21989       HIOS           6
# 1                 2014        AK     21989       HIOS           6
# 2                 2014        AK     21989       HIOS           6
# 3                 2014        AK     21989       HIOS           6
# 4                 2014        AK     21989       HIOS           6
# ...                ...       ...       ...        ...         ...
# 12694440          2016        WV     96480      SERFF           2
# 12694441          2016        WV     96480      SERFF           2
# 12694442          2016        WV     96480      SERFF           2
# 12694443          2016        WV     96480      SERFF           2
# 12694444          2016        WV     96480      SERFF           2
#
#                    ImportDate  IssuerId2  FederalTIN RateEffectiveDate  \
# 0         2014-03-19 07:06:49      21989  93-0438772        2014-01-01
# ...

# %%
servicearea = pd.read_csv('ServiceArea.csv')
servicearea
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              2014        PA     22444       HIOS           9
# 1              2014        PA     22444       HIOS           9
# 2              2014        PA     22444       HIOS           9
# 3              2014        PA     22444       HIOS           9
# 4              2014        PA     22444       HIOS           9
# ...             ...       ...       ...        ...         ...
# 42242          2016        WV     96480      SERFF           2
# 42243          2016        WV     96480      SERFF           2
# 42244          2016        WV     96480      SERFF           2
# 42245          2016        WV     96480      SERFF           2
# 42246          2016        WV     96480      SERFF           2
#
#                 ImportDate  IssuerId2 StateCode2 ServiceAreaId  \
# 0      2014-01-21 08:29:49      22444         PA        PAS001
# 1      2014-01-21 08:29:49      22444         PA        PAS001
# ...
